# %% [markdown]
# 导入numpy

# %%
import numpy as np

# %%
arr1=np.array([6,2,-7,2,8,-2,1])
print(arr1)
# Out:
# [ 6  2 -7  2  8 -2  1]

# %%
arr2=np.array([[1,3,5],[2,4,6]])
arr2
# Out:
# array([[1, 3, 5],
#        [2, 4, 6]])

# %%
print(arr1.ndim)
print(arr2.ndim)
print(arr1.shape)
print(arr2.shape)
print(arr1.size)
print(arr2.size)
print(arr1.dtype)
print(arr2.dtype)
# Out:
# 1
# 2
# (7,)
# (2, 3)
# 7
# 6
# int64
# int64

# %%
arry_even=np.arange(10,21,2)
arry_even
# Out:
# array([10, 12, 14, 16, 18, 20])
