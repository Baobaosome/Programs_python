# %%
import numpy as np

# %%
arr1=np.array([1,3,2,4,9,])
arr2=np.zeros(5)
arr3=np.ones(3)
print(arr1)
print(arr2)
print(arr3)
# Out:
# [1 3 2 4 9]
# [0. 0. 0. 0. 0.]
# [1. 1. 1.]

# %%
arr4=np.concatenate([arr1,arr2,arr3])
arr4
# Out:
# array([1., 3., 2., 4., 9., 0., 0., 0., 0., 0., 1., 1., 1.])

# %%
print(arr1.sort())
arr1
# Out:
# None
# array([1, 2, 3, 4, 9])

# %%
print(arr1[2])
arr1[-3]
# Out:
# 3
# np.int64(3)

# %%
print(arr1[1:4])
arr1[slice(1,4)]
# Out:
# [2 3 4]
# array([2, 3, 4])

# %%
arr1+arr2
# Out:
# array([1., 2., 3., 4., 9.])

# %%
print(arr1.max())
print(arr1.min())
print(arr1.sum())
print(arr1.mean())
arr1.mean()
# Out:
# 9
# 1
# 19
# 3.8
# np.float64(3.8)

# %%
arr1[(arr1<5)&(arr1>2)]
# Out:
# array([3, 4])
